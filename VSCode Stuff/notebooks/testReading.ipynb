# %%
import numpy as np
import pandas as pd
import plotly.graph_objects as go

drivingTestData = pd.read_csv('../data/RSA Driving Test Pass Rate.csv')
drivingTestData.head(20)
# Out:
#            Statistic Label         Month Driving Test Categories  \
# 0   Driving Test Pass Rate  2021 January     All Test Categories
# 1   Driving Test Pass Rate  2021 January     All Test Categories
# 2   Driving Test Pass Rate  2021 January     All Test Categories
# 3   Driving Test Pass Rate  2021 January     All Test Categories
# 4   Driving Test Pass Rate  2021 January     All Test Categories
# 5   Driving Test Pass Rate  2021 January     All Test Categories
# 6   Driving Test Pass Rate  2021 January     All Test Categories
# 7   Driving Test Pass Rate  2021 January     All Test Categories
# 8   Driving Test Pass Rate  2021 January     All Test Categories
# 9   Driving Test Pass Rate  2021 January     All Test Categories
# 10  Driving Test Pass Rate  2021 January     All Test Categories
# 11  Driving Test Pass Rate  2021 January     All Test Categories
# 12  Driving Test Pass Rate  2021 January     All Test Categories
# ...
